# %%
import pandas as pd

# %%
def get_archive_slice(date):
    archive = pd.read_csv("app/scraped_data/archive.csv",  parse_dates=['message_date'])
    mask = (archive['message_date'] >= date)
    return archive[mask]

# %%
date = '2023-05-21'

# %%
get_archive_slice(date)
# Out:
#                                    file_name  \
# 1310                                   1.mp4
# 1311  53зновуїбашитьпідарівуїбучомумісці.mp4
# 1312       @DeepStateUA_biden_g7_bakhmut.mp4
# 1313                           59відео12.mp4
# 1314                      діпстейтмомент.mp4
# 1315                                   1.mp4
# 1316                                   1.mp4
# 1317                               бнр 3.MOV
# 1318                               бнр 2.MP4
# 1319                               бнр 1.MP4
# 1320                                 бнр.mp4
# 1321                               бнр 5.mp4
# 1322                               бнр 4.MOV
# 1323                      4x5-TG-DR-12mb.mp4
#
#                                            message_text  \
# 1310  18,05,23 Артёмовск - Часов Яр - Григоровка\n\n...
# 1311  🗡 Бійці 53 ОМБр поділилися кадрами як зупиняли...
# 1312  🇺🇸Байден у своїй промові на саміті G7 у Хіросі...
# ...
